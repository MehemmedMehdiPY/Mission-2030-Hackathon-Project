# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/monthly datasets for each location/September.csv')

# %%
FILEPATH = '../data/locations/'
FILENAME = 'geospatial.csv'
geo_df = pd.read_csv(FILEPATH + FILENAME)

# %%
df.head(10)
# Out:
#    Solar Potential    Landcover  Soil Moisture  Soil Texture      Slope
# 0       154.815897  5030.627445       0.213664  11853.450220  31.519659  \
# 1       152.629103  2333.382047       0.234046   7449.897142  22.879574
# 2       150.486632  2754.700458       0.213664  11025.815270  29.273340
# 3       153.690789  3972.602137       0.210990   7635.981889   4.760822
# 4       154.210562  4149.814222       0.210990   9220.060659  17.690387
# 5       148.334960     0.000000       0.224990   3172.311284  29.420431
# 6       151.803469     0.000000       0.212777   3587.370113  35.268259
# 7       153.574444  2086.587694       0.212777   6031.618971  16.634002
# 8       154.109736  5088.779720       0.215566   8620.567681   2.204745
# 9       148.454748     0.000000       0.228703   2047.451234  15.744254
#
#        Aspect
# 0   28.801444
# 1  118.691951
# 2   37.270103
# 3   92.626847
# 4   80.913842
# 5  148.976753
# 6  172.446560
# 7   80.109610
# 8  149.866752
# 9   78.910653

# %%
newdf = pd.concat((geo_df[['Latitude', 'Longitude']], df), axis = 1)

# %%
newdf.head(10)
# Out:
#    Latitude  Longitude  Solar Potential    Landcover  Soil Moisture
# 0     38.93      46.58       154.815897  5030.627445       0.213664  \
# 1     38.97      46.58       152.629103  2333.382047       0.234046
# 2     38.97      46.50       150.486632  2754.700458       0.213664
# 3     38.97      46.62       153.690789  3972.602137       0.210990
# 4     38.97      46.66       154.210562  4149.814222       0.210990
# 5     39.01      46.58       148.334960     0.000000       0.224990
# 6     39.01      46.62       151.803469     0.000000       0.212777
# 7     39.01      46.66       153.574444  2086.587694       0.212777
# 8     39.01      46.70       154.109736  5088.779720       0.215566
# 9     39.05      46.58       148.454748     0.000000       0.228703
#
#    Soil Texture      Slope      Aspect
# 0  11853.450220  31.519659   28.801444
# 1   7449.897142  22.879574  118.691951
# 2  11025.815270  29.273340   37.270103
# 3   7635.981889   4.760822   92.626847
# ...

# %%
sns.displot(newdf['Solar Potential'])
